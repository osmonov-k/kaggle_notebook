# %% [markdown]
# ### Nobel nomination
# #### Analysis of the smartest badasses and a bit sexist incline

# %%
# import libraries
import pandas as pd
import numpy as np
import pandas_profiling
import missingno as msno
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ##### Data Analysis Process
# ##### Stage 1
# - Question Data
# - Exploration Data Analysis
# * Missing data
# * Tydy?
#
# ##### Stage 2
# - Plan analysis

# %%
# uploading file 
df = pd.read_csv('archive.csv', index_col='Year')

# %%
df.head()
# Out:
#         Category                                           Prize  \
# Year
# 1901   Chemistry               The Nobel Prize in Chemistry 1901
# 1901  Literature              The Nobel Prize in Literature 1901
# 1901    Medicine  The Nobel Prize in Physiology or Medicine 1901
# 1901       Peace                      The Nobel Peace Prize 1901
# 1901       Peace                      The Nobel Peace Prize 1901
#
#                                              Motivation Prize Share  \
# Year
# 1901  "in recognition of the extraordinary services ...         1/1
# 1901  "in special recognition of his poetic composit...         1/1
# 1901  "for his work on serum therapy, especially its...         1/1
# 1901                                                NaN         1/2
# 1901                                                NaN         1/2
#
#       Laureate ID Laureate Type                     Full Name  Birth Date  \
# Year
# ...

# %%
df.columns = [x.replace('.', '').replace(' ', '_') for x in df.columns]

# %%
df.columns
# Out:
# Index(['Category', 'Prize', 'Motivation', 'Prize_Share', 'Laureate_ID',
#        'Laureate_Type', 'Full_Name', 'Birth_Date', 'Birth_City',
#        'Birth_Country', 'Sex', 'Organization_Name', 'Organization_City',
#        'Organization_Country', 'Death_Date', 'Death_City', 'Death_Country'],
#       dtype='object')

# %%
g = df.groupby(['Birth_City']).sum()

# %%
year_category = df.groupby(['Year', 'Category'])['Laureate_ID'].count().reset_index()

# %%
plt.style.use('fivethirtyeight')
g = sns.FacetGrid(year_category, col='Category', hue='Category', col_wrap=2)
g = g.map(plt.plot, 'Year', 'Laureate_ID')
g = g.map(plt.fill_between, 'Year', 'Laureate_ID', alpha=0.2).set_titles('{col_name} Category')
plt.show()

# %% [markdown]
# ### Nobel Prize by Country/Category/Sex

# %%
sex = df.groupby('Sex').count()

# %%
sex.index
# Out:
# Index(['Female', 'Male'], dtype='object', name='Sex')

# %%
plt.rcParams['figure.figsize'] = [13, 7]
sns.barplot(x=sex.index, y='Category', data=sex)
plt.xticks(rotation=90)
plt.title("Nobel Prizes by sex")
plt.show()

# %%
year = df.reset_index()['Year'].value_counts()

# %%
sns.lineplot(year.index, year.values, color='red')

plt.xticks(rotation=90)
plt.title('Nobel Prizes by Year')
# sns.set_style('ticks', {'xticks.major.size': 5})
plt.show()

# %%
df.head(2)
# Out:
#         Category                               Prize  \
# Year
# 1901   Chemistry   The Nobel Prize in Chemistry 1901
# 1901  Literature  The Nobel Prize in Literature 1901
#
#                                              Motivation Prize_Share  \
# Year
# 1901  "in recognition of the extraordinary services ...         1/1
# 1901  "in special recognition of his poetic composit...         1/1
#
#       Laureate_ID Laureate_Type                     Full_Name  Birth_Date  \
# Year
# 1901          160    Individual  Jacobus Henricus van 't Hoff  1852-08-30
# 1901          569    Individual               Sully Prudhomme  1839-03-16
#
#      Birth_City Birth_Country   Sex  Organization_Name Organization_City  \
# Year
# 1901  Rotterdam   Netherlands  Male  Berlin University            Berlin
# 1901      Paris        France  Male                NaN               NaN
#
#      Organization_Country  Death_Date Death_City Death_Country
# Year
# ...

# %%
sns.barplot(y=df.Category.value_counts(), x=df.Category.value_counts().index)
plt.xticks(rotation=90)
plt.show()

# %%
df.Birth_Country.value_counts().nlargest(10)
# Out:
# United States of America    276
# United Kingdom               88
# Germany                      70
# France                       53
# Sweden                       30
# Japan                        29
# Russia                       20
# Netherlands                  19
# Italy                        18
# Canada                       18
# Name: Birth_Country, dtype: int64

# %%
sns.barplot(x=df.Birth_Country.value_counts().nlargest(10).index, y=df.Birth_Country.value_counts().nlargest(10))
plt.xticks(rotation=90)
plt.title('Top 10')
plt.show()

# %%
city = df['Birth_City'].value_counts().head(10)
city.head()
# Out:
# New York, NY    48
# Paris           25
# London          21
# Vienna          16
# Chicago, IL     13
# Name: Birth_City, dtype: int64

# %%
sns.barplot(x=city.index, y=city.values)
plt.xticks(rotation=90)
plt.title('Top 10 City, in which nobel prize winners born')
plt.show()

# %%
df = df.reset_index()

# %%
# df
df['Birth_Date'] = pd.to_datetime(df['Birth_Date'])
df['Age'] = df['Year']-df['Birth_Date'].dt.year

# %%
# Out:
# 0      49.0
# 1      62.0
# 2      47.0
# 3      73.0
# 4      79.0
#        ...
# 964    71.0
# 965    65.0
# 966    82.0
# 967    65.0
# 968    73.0
# Name: Age, Length: 969, dtype: float64

# %%
# Calculating the proportion of USA born winners per decade
df['usa_born_winner'] = df['Birth_Country']=="United States of America"
df['decade'] = (np.floor(df['Year']/10)*10).astype(int)
prop_usa_winners = df.groupby('decade', as_index=False)['usa_born_winner'].mean()

# Display the proportions of USA born winners per decade
display(prop_usa_winners)
# Out:
#     decade  usa_born_winner
# 0     1900         0.017241
# 1     1910         0.075000
# 2     1920         0.074074
# 3     1930         0.241935
# 4     1940         0.288889
# 5     1950         0.278481
# 6     1960         0.262500
# 7     1970         0.308411
# 8     1980         0.313131
# 9     1990         0.392523
# 10    2000         0.414286
# 11    2010         0.336735

# %%
df['Birth Year'] = df['Birth_Date'].str[0:4]
df['Birth Year'] = df['Birth Year'].replace(to_replace="nan", value=0)

# %%
df['Birth Year'] = df['Birth Year'].apply(pd.to_numeric)

# %%
df['Age'] = df['Year'] - df['Birth Year']

# %%
sns.jointplot(x="Year",
        y="Age",
        kind='reg',
        data=df)

plt.show()

# %%
org = df['Organization_Name'].value_counts().reset_index().head(20)

sns.barplot(x='Organization_Name',y='index',data=org)
plt.xticks(rotation=90)
plt.ylabel('Organization Name')
plt.xlabel('Count')
plt.show()

# %%
copy = df[:]

# copy.Birth_date = pd.to_datetime(copy.Birth_Date)

# %%
df.Birth_Date.replace(to_replace='00-00', value='01-01', inplace=True, regex=True)

# %%
copy[copy['Birth_Date']=='1943-00-00']
# Out:
# Empty DataFrame
# Columns: [Category, Prize, Motivation, Prize_Share, Laureate_ID, Laureate_Type, Full_Name, Birth_Date, Birth_City, Birth_Country, Sex, Organization_Name, Organization_City, Organization_Country, Death_Date, Death_City, Death_Country]
# Index: []

# %%
import re

# %%
re.sub('00-00')
